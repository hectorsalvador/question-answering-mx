# %% [markdown]
# # Question Answering Machine
#
# ### Final Project for AMLPP
#
# ### Carlos Grandet & Hector Salvador
#
# The following is a demo for a question answering machine (QAM) that we build for a machine learning class. The QAM uses several NLP tools such as Stanford POSTagger, Word2Vec and
# BM25.

# %%
# First step, load the relevant libraries and classes

from question_processing import Question
from synonyms import Synonyms
from Word2VecModel import W2V_Model 
from spanish_tagger import Spanish_Postagger
from query import Query
from index import go
from retrieval import ScoreParagraphs
from ngrams import retrieve_model
import json
import math

# Then name the different files you will use to make the code work

tagfile = 'stanford-postagger-full-2016-10-31/models/spanish.tagger'
jarfile = 'stanford-postagger-full-2016-10-31/stanford-postagger.jar'

# Data for synonyms API
APIfile = 'http://store.apicultur.com/api/sinonimosporpalabra/1.0.0/' 
token = 'f7JE_2svUVwP5ARGfw8aQhnLXlga'

# Data for w2v model
w2vfile = 'SBW-vectors-300-min5.txt'

# Data for question_type
question_json = 'Data/question_type.json'
stopwords = 'Data/stopwords.json'

# %% [markdown]
# ### Create a Query class, which allows you to make questions, get queries and find related words.
#
# Creating this query might take a while, since you need to load a Word2Vec model that is over 2.5 GB!!! We advise running the following line of code only once, as it might take around 10 minutes for it to run.
#
# ## RUN ONCE

# %%
query = Query(APIfile, token, tagfile, jarfile, 
    w2vfile)

# %% [markdown]
# Once we have created the Query class, we can start asking various questions

# %%
question = "¿Cuál es el castigo por homicidio?" #Translation: What is the punishment for murder?

#set_question loads a question and a json file with info about the words that represent 
#a question type (i.e. time: years, period, days, etc )
query.set_question(question, question_json)

#get_query gives you a specific query list
query.get_query(stopwords)
# Out:
# http://store.apicultur.com/api/sinonimosporpalabra/1.0.0/homicidio
# Bearer f7JE_2svUVwP5ARGfw8aQhnLXlga

# %% [markdown]
# You can access the query selected for that question and the question type with
# the following attributes

# %%
print(query.query)
print(query.qtype)
# Out:
# {'culposo', 'crimen', 'doloso', 'homicidio', 'delito', 'asesinato', 'homicido'}
# ['años']

# %% [markdown]
# You can also add words to the query, if you want

# %%
query.add_words(["asesinato", "imprudencial"])

# %% [markdown]
# You can also remove words

# %%
query.remove_words(["asesinato", "doloso"])

# %%
query.query
# Out:
# {'crimen', 'culposo', 'delito', 'homicidio', 'homicido', 'imprudencial'}

# %% [markdown]
# Finally, you can play with word to vec to find other words that could match your query or find words that do not belong there

# %%
query.W2V.find_concepts(positive = ["rey", "mujer"], negative = ["hombre"], top_n = 1)
# Out:
# ['reina']

# %%
query.W2V.intruder(["rana", "pato", "simio", "pelota"])
# Out:
# 'pelota'

# %% [markdown]
# ### Once you have a query, the next step is to use information retrieval to find the relevant documents
#
# We will assume that the user has: the .txt documents in a folder called "./leyes", the "docnames.csv" file in a folder called "./doc". Run first the following script to create a set of indices to make queries efficient. Note that this can take up to 5 minutes.
#
# ## RUN IT ONLY ONCE

# %%
go()
# Out:
# Using stemmed words.
# Processing 2_241213..
#   ..finished with 2_241213.
# Processing 3_250117..
#   ..finished with 3_250117.
# Processing 4_160516..
#   ..finished with 4_160516.
# Processing 6..
#   ..finished with 6.
# Processing 8_270117..
#   ..finished with 8_270117.
# Processing CMPP..
#   ..finished with CMPP.
# Processing CNPP_170616..
#   ..finished with CNPP_170616.
# Processing 9_180716..
#   ..finished with 9_180716.
# Processing 10_270614..
#   ..finished with 10_270614.
# Processing 11..
#   ..finished with 11.
# Processing 79..
#   ..finished with 79.
# Processing 12_270117..
#   ..finished with 12_270117.
# Processing 13_191216..
#   ..finished with 13_191216.
# Processing 14_101114..
#   ..finished with 14_101114.
# Processing 15_080616..
#   ..finished with 15_080616.
# Processing 16_240316..
#   ..finished with 16_240316.
# Processing 17..
#   ..finished with 17.
# Processing 19..
#   ..finished with 19.
# Processing LAmp_170616..
#   ..finished with LAmp_170616.
# Processing 21..
#   ..finished with 21.
# Processing 22_270117..
#   ..finished with 22_270117.
# Processing 270_191214..
#   ..finished with 270_191214.
# Processing LAPP_210416..
#   ..finished with LAPP_210416.
# Processing 24_171215..
#   ..finished with 24_171215.
# Processing 25_101016..
#   ..finished with 25_101016.
# Processing LAAT..
#   ..finished with LAAT.
# Processing LBOGM..
#   ..finished with LBOGM.
# Processing LCEC..
#   ..finished with LCEC.
# Processing 27_101016..
#   ..finished with 27_101016.
# Processing 238..
#   ..finished with 238.
# Processing 242_081215..
#   ..finished with 242_081215.
# Processing 28..
#   ..finished with 28.
# Processing 29..
#   ..finished with 29.
# Processing 30..
#   ..finished with 30.
# Processing LCID_171215..
#   ..finished with LCID_171215.
# Processing 31_180716..
#   ..finished with 31_180716.
# Processing 235..
#   ..finished with 235.
# Processing LDSCA..
#   ..finished with LDSCA.
# Processing 33..
#   ..finished with 33.
# Processing LDFEFM_270416..
#   ..finished with LDFEFM_270416.
# Processing 252..
#   ..finished with 252.
# Processing LEMEFAM..
#   ..finished with LEMEFAM.
# Processing LEG_110814..
#   ..finished with LEG_110814.
# Processing 246..
#   ..finished with 246.
# Processing 35..
#   ..finished with 35.
# Processing 36..
#   ..finished with 36.
# Processing LFEA..
#   ..finished with LFEA.
# Processing LFRCF..
#   ..finished with LFRCF.
# Processing LFLL_171215..
#   ..finished with LFLL_171215.
# Processing LFAAR..
#   ..finished with LFAAR.
# Processing 69_130614..
#   ..finished with 69_130614.
# Processing LHidro_151116..
#   ..finished with LHidro_151116.
# Processing LIF_2017..
#   ..finished with LIF_2017.
# Processing LIH_060117..
#   ..finished with LIH_060117.
# Processing 43_170616..
#   ..finished with 43_170616.
# Processing LISF..
#   ..finished with LISF.
# Processing 44_181215..
#   ..finished with 44_181215.
# Processing LANSI_110814..
#   ..finished with LANSI_110814.
# Processing 45..
#   ..finished with 45.
# Processing LCFE_110814..
#   ..finished with LCFE_110814.
# Processing 46..
#   ..finished with 46.
# Processing 47_270117..
#   ..finished with 47_270117.
# Processing 261_070416..
#   ..finished with 261_070416.
# Processing LESS_301215..
#   ..finished with LESS_301215.
# Processing LIElec_110814..
#   ..finished with LIElec_110814.
# Processing LPF..
#   ..finished with LPF.
# Processing 50_010616..
#   ..finished with 50_010616.
# Processing 245_271216..
#   ..finished with 245_271216.
# Processing LIGIE..
#   ..finished with LIGIE.
# Processing 51_270115..
#   ..finished with 51_270115.
# Processing LORCME_110814..
#   ..finished with LORCME_110814.
# Processing 52..
#   ..finished with 52.
# Processing LMigra_210416..
#   ..finished with LMigra_210416.
# Processing 53..
#   ..finished with 53.
# Processing LNCM_191216..
#   ..finished with LNCM_191216.
# Processing 56_130116..
#   ..finished with 56_130116.
# Processing 57..
#   ..finished with 57.
# Processing LPM_110814..
#   ..finished with LPM_110814.
# Processing 59_281116..
#   ..finished with 59_281116.
# Processing 60_171215..
#   ..finished with 60_171215.
# Processing LPO..
#   ..finished with LPO.
# Processing LPDB..
#   ..finished with LPDB.
# Processing 62..
#   ..finished with 62.
# Processing 63..
#   ..finished with 63.
# Processing 64..
#   ..finished with 64.
# Processing 65_191216..
#   ..finished with 65_191216.
# Processing 66..
#   ..finished with 66.
# Processing 67..
#   ..finished with 67.
# Processing LSegNa..
# Processing 255..
#   ..finished with 255.
# Processing 70..
#   ..finished with 70.
# Processing 71..
#   ..finished with 71.
# Processing LTF..
#   ..finished with LTF.
# Processing LTE..
#   ..finished with LTE.
# Processing 256..
#   ..finished with 256.
# Processing LUC..
#   ..finished with LUC.
# Processing LVZMM..
#   ..finished with LVZMM.
# Processing 73_181215..
#   ..finished with 73_181215.
# Processing LViv_200415..
#   ..finished with LViv_200415.
# Processing 74..
#   ..finished with 74.
# Processing 75..
#   ..finished with 75.
# Processing LFMPED_110814..
#   ..finished with LFMPED_110814.
# Processing 77_301116..
#   ..finished with 77_301116.
# Processing 78_271216..
#   ..finished with 78_271216.
# Processing LISR_301116..
#   ..finished with LISR_301116.
# Processing 84_270115..
#   ..finished with 84_270115.
# Processing LISSSTE_240316..
#   ..finished with LISSSTE_240316.
# Processing 86_240117..
#   ..finished with 86_240117.
# Processing LIFNCT..
#   ..finished with LIFNCT.
# Processing 87_020415..
#   ..finished with 87_020415.
# Processing 88_040615..
#   ..finished with 88_040615.
# Processing LINEE_270117..
#   ..finished with LINEE_270117.
# Processing LMV..
#   ..finished with LMV.
# Processing LRNDPED..
#   ..finished with LRNDPED.
# Processing 269..
#   ..finished with 269.
# Processing 92_121115..
#   ..finished with 92_121115.
# Processing 93_171215..
#   ..finished with 93_171215.
# Processing 96_010616..
#   ..finished with 96_010616.
# Processing 97..
#   ..finished with 97.
# Processing 98_040615..
#   ..finished with 98_040615.
# Processing 260..
#   ..finished with 260.
# Processing 239_310115..
#   ..finished with 239_310115.
# Processing LSNIEG_270117..
#   ..finished with LSNIEG_270117.
# Processing LSPREM_181215..
#   ..finished with LSPREM_181215.
# Processing 100..
#   ..finished with 100.
# Processing LFACP_180716..
#   ..finished with LFACP_180716.
# Processing 101_160616..
#   ..finished with 101_160616.
# Processing LFA..
#   ..finished with LFA.
# Processing 102_12nov15..
#   ..finished with 102_12nov15.
# Processing 103_171215..
#   ..finished with 103_171215.
# Processing LFCE_270117..
#   ..finished with LFCE_270117.
# Processing LFCP..
# Processing 105..
#   ..finished with 105.
# Processing 106_170616..
#   ..finished with 106_170616.
# Processing 107_231216..
#   ..finished with 107_231216.
# Processing 136_270416..
#   ..finished with 136_270416.
# Processing LFED_120116..
#   ..finished with LFED_120116.
# Processing 266..
#   ..finished with 266.
# Processing 109..
#   ..finished with 109.
# Processing 110_181215..
#   ..finished with 110_181215.
# Processing LFDC..
#   ..finished with LFDC.
# Processing 111..
#   ..finished with 111.
# Processing LFPRH_301215..
#   ..finished with LFPRH_301215.
# Processing 112..
#   ..finished with 112.
# Processing LFPCA_270117..
#   ..finished with LFPCA_270117.
# Processing LFPCCS..
#   ..finished with LFPCCS.
# Processing 113_281216..
#   ..finished with 113_281216.
# Processing LFPDPPP..
#   ..finished with LFPDPPP.
# Processing LFRA..
#   ..finished with LFRA.
# Processing LFRPE..
#   ..finished with LFRPE.
# Processing 240_180716..
#   ..finished with 240_180716.
# Processing 115_180716..
#   ..finished with 115_180716.
# Processing LFSA..
#   ..finished with LFSA.
# Processing 117..
#   ..finished with 117.
# Processing LFSP..
#   ..finished with LFSP.
# Processing LFTR_270117..
#   ..finished with LFTR_270117.
# Processing LFTAIP_270117..
# Processing 120..
#   ..finished with 120.
# Processing LFZEE..
#   ..finished with LFZEE.
# Processing 122_130116..
#   ..finished with 122_130116.
# Processing 123_120117..
#   ..finished with 123_120117.
# Processing 124..
#   ..finished with 124.
# Processing 125_120615..
#   ..finished with 125_120615.
# Processing 126..
#   ..finished with 126.
# Processing LFCSQ..
#   ..finished with LFCSQ.
# Processing 127..
#   ..finished with 127.
# Processing 251..
#   ..finished with 251.
# Processing LFPIORPI..
#   ..finished with LFPIORPI.
# Processing LFPPIPP_170616..
#   ..finished with LFPPIPP_170616.
# Processing 262_011216..
#   ..finished with 262_011216.
# Processing 129..
#   ..finished with 129.
# Processing LFPSDMH..
#   ..finished with LFPSDMH.
# Processing 130_181215..
#   ..finished with 130_181215.
# Processing 131_280115..
#   ..finished with 131_280115.
# Processing LGAMVLV_171215..
#   ..finished with LGAMVLV_171215.
# Processing LGAHOTDU_281116..
#   ..finished with LGAHOTDU_281116.
# Processing 134_171215..
#   ..finished with 134_171215.
# Processing 267_010616..
#   ..finished with 267_010616.
# Processing LGCC_010616..
#   ..finished with LGCC_010616.
# Processing LGCG_180716..
#   ..finished with LGCG_180716.
# Processing LGCFD_250117..
#   ..finished with LGCFD_250117.
# Processing 257_171215..
#   ..finished with 257_171215.
# Processing 259_240117..
#   ..finished with 259_240117.
# Processing 264_010616..
#   ..finished with 264_010616.
# Processing 137_010616..
#   ..finished with 137_010616.
# Processing LGIPE_270117..
#   ..finished with LGIPE_270117.
# Processing LGIFE..
#   ..finished with LGIFE.
# Processing LGDNNA_041214..
#   ..finished with LGDNNA_041214.
# Processing 139..
#   ..finished with 139.
# Processing LGPP_130815..
#   ..finished with LGPP_130815.
# Processing LGPAS_040615..
#   ..finished with LGPAS_040615.
# Processing 140_011215..
#   ..finished with 140_011215.
# Processing LGPSACDII_070416..
#   ..finished with LGPSACDII_070416.
# Processing LGPC_030614..
#   ..finished with LGPC_030614.
# Processing LGPDPPSO..
#   ..finished with LGPDPPSO.
# Processing LGRA..
#   ..finished with LGRA.
# Processing 142_270117..
#   ..finished with 142_270117.
# Processing 143..
#   ..finished with 143.
# Processing 144_140316..
#   ..finished with 144_140316.
# Processing 145_130614..
#   ..finished with 145_130614.
# Processing LGTAIP..
#   ..finished with LGTAIP.
# Processing LGT_171215..
#   ..finished with LGT_171215.
# Processing LGV_030117..
#   ..finished with LGV_030117.
# Processing 146_191216..
#   ..finished with 146_191216.
# Processing 148_240117..
#   ..finished with 148_240117.
# Processing LGSPD..
#   ..finished with LGSPD.
# Processing 149..
#   ..finished with 149.
# Processing LGSNA..
#   ..finished with LGSNA.
# Processing LGSNSP_170616..
#   ..finished with LGSNSP_170616.
# Processing LGMDE_270614..
#   ..finished with LGMDE_270614.
# Processing LGCT..
#   ..finished with LGCT.
# Processing LGAPPCEA_270516..
#   ..finished with LGAPPCEA_270516.
# Processing LGIMH_240316..
#   ..finished with LGIMH_240316.
# Processing LGIPD_171215..
#   ..finished with LGIPD_171215.
# Processing LGPSVD..
#   ..finished with LGPSVD.
# Processing 263_220515..
#   ..finished with 263_220515.
# Processing LGPSEDMTP..
#   ..finished with LGPSEDMTP.
# Processing LGPSDMS_170616..
#   ..finished with LGPSDMS_170616.
# Processing 151_110814..
#   ..finished with 151_110814.
# Processing 152..
#   ..finished with 152.
# Processing LNEP..
#   ..finished with LNEP.
# Processing LNMASCMP_291214..
#   ..finished with LNMASCMP_291214.
# Processing LNSIJPA..
#   ..finished with LNSIJPA.
# Processing 153_191216..
#   ..finished with 153_191216.
# Processing 249..
#   ..finished with 249.
# Processing 248..
#   ..finished with 248.
# Processing 155..
#   ..finished with 155.
# Processing LOPDC..
#   ..finished with LOPDC.
# Processing LOPGJDF..
#   ..finished with LOPGJDF.
# Processing LOPGR_180716..
#   ..finished with LOPGR_180716.
# Processing LOUAAAN..
#   ..finished with LOUAAAN.
# Processing 157..
#   ..finished with 157.
# Processing 158..
#   ..finished with 158.
# Processing 159..
#   ..finished with 159.
# Processing 162..
#   ..finished with 162.
# Processing 234..
#   ..finished with 234.
# Processing 164..
#   ..finished with 164.
# Processing 165..
#   ..finished with 165.
# Processing 166..
#   ..finished with 166.
# Processing 167..
#   ..finished with 167.
# Processing 168_270117..
#   ..finished with 168_270117.
# Processing 243..
#   ..finished with 243.
# Processing 169_061114..
#   ..finished with 169_061114.
# Processing 170_171215..
#   ..finished with 170_171215.
# Processing 171..
#   ..finished with 171.
# Processing 172_031116..
#   ..finished with 172_031116.
# Processing 173..
#   ..finished with 173.
# Processing LOTFJA..
#   ..finished with LOTFJA.
# Processing 176..
#   ..finished with 176.
# Processing LDVUMA_301216..
#   ..finished with LDVUMA_301216.
# Processing 247_011216..
#   ..finished with 247_011216.
# Processing 177..
#   ..finished with 177.
# Processing LUPDECR..
#   ..finished with LUPDECR.
# Processing LIISPCEN..
#   ..finished with LIISPCEN.
# Processing 268..
#   ..finished with 268.
# Processing LCACSEFAM..
#   ..finished with LCACSEFAM.
# Processing 182..
#   ..finished with 182.
# Processing 183..
#   ..finished with 183.
# Processing LPPDDHP..
#   ..finished with LPPDDHP.
# Processing LTOSF..
#   ..finished with LTOSF.
# Processing LRASCAP_280414..
#   ..finished with LRASCAP_280414.
# Processing LRAF..
#   ..finished with LRAF.
# Processing 237..
#   ..finished with 237.
# Processing 187_291214..
#   ..finished with 187_291214.
# Processing LFFASETMM..
#   ..finished with LFFASETMM.
# Processing 190_280414..
#   ..finished with 190_280414.
# Processing 192..
#   ..finished with 192.
# Processing 193_171215..
#   ..finished with 193_171215.
# Processing LANEM..
#   ..finished with LANEM.
# Processing LAEM..
#   ..finished with LAEM.
# Processing 195..
#   ..finished with 195.
# Processing 196..
#   ..finished with 196.
# Processing 197..
#   ..finished with 197.
# Processing 199_291214..
#   ..finished with 199_291214.
# Processing 200_291214..
#   ..finished with 200_291214.
# Processing 202..
#   ..finished with 202.
# Processing LRArt76_fracVI..
#   ..finished with LRArt76_fracVI.
# Processing 203..
#   ..finished with 203.
# Processing 204..
#   ..finished with 204.
# Processing 205_270115..
#   ..finished with 205_270115.
# Processing 207..
#   ..finished with 207.
# Processing 208..
#   ..finished with 208.
# Processing LRArt6_MDR_041115..
#   ..finished with LRArt6_MDR_041115.
# Processing 209_080616..
#   ..finished with 209_080616.
# Processing 23..
#   ..finished with 23.
# Processing 40_041115..
#   ..finished with 40_041115.
# Processing 211..
#   ..finished with 211.
# Processing 213_011216..
#   ..finished with 213_011216.
# Processing 215..
#   ..finished with 215.
# Processing 271..
#   ..finished with 271.
# Processing 216..
#   ..finished with 216.
# Processing LRPCAP_301014..
#   ..finished with LRPCAP_301014.
# Processing 218..
#   ..finished with 218.
# Processing PEF_2017..
#   ..finished with PEF_2017.
# Processing Reg_Diputados_281216..
#   ..finished with Reg_Diputados_281216.
# Processing Reg_Senado_221214..
#   ..finished with Reg_Senado_221214.
# Processing 219..
#   ..finished with 219.
# Processing Dec_HEEUM_130310..
#   ..finished with Dec_HEEUM_130310.
# Finished processing documents. Stored in their respective folders.

# %% [markdown]
# The following code prioritizes the articles that are relevant to our search, based on the words provided by the query.

# %%
top_results = 20
words = list(query.query)
test = ScoreParagraphs(question, words, stem=True)
results = test.texts(top_results, method='bm25')
# Out:
# Working with stemmed words: ['culpos', 'crim', 'imprudencial', 'homicidi', 'delit', 'homic']
#                                                  text     score  \
# 0    309 Se deroga\n   \nCAPITULO III\nReglas comu...  1.838249
# 1    313 Si el occiso o suicida fuere menor de eda...  1.614150
# 2    59 Bis Se deroga\n   \nCAPITULO II\nAplicació...  1.512563
# 3    302 Comete el delito de homicidio el que priv...  1.497126
# 4    320 Al responsable de un homicidio calificado...  1.252807
# 5    307 Al responsable de cualquier homicidio sim...  0.786295
# 6    301 De las lesiones que a una persona cause a...  0.673755
# 7    137 Cuando durante una rebelión se cometan lo...  0.616268
# 8    315 Bis Se impondrá la pena del artículo 320 ...  0.538570
# 9    308 Si el homicidio se comete en riña se apli...  0.516264
# 10   315 Se entiende que las lesiones y el homicid...  0.463249
# 11   61 En los casos a que se refiere la primera p...  0.453452
# 12   322 Además de las sanciones que señalan los d...  0.415243
# 13   341 Al que habiendo atropellado a una persona...  0.395046
# 14   321 Bis No se procederá contra quien culposam...  0.385372
# 15   66 En caso de que el error a que se refiere e...  0.228436
# 16   60 En los casos de delitos culposos se impond...  0.212391
# 17   71 El juez dejará sin efecto la sustitución y...  0.198941
# 18   228 Los profesionistas artistas o técnicos y ...  0.178967
# 19   280 Se impondrá prisión de tres días a dos añ...  0.177381
#
#                      Law
# 0   CÓDIGO Penal Federal
# 1   CÓDIGO Penal Federal
# 2   CÓDIGO Penal Federal
# 3   CÓDIGO Penal Federal
# 4   CÓDIGO Penal Federal
# 5   CÓDIGO Penal Federal
# 6   CÓDIGO Penal Federal
# 7   CÓDIGO Penal Federal
# 8   CÓDIGO Penal Federal
# 9   CÓDIGO Penal Federal
# 10  CÓDIGO Penal Federal
# 11  CÓDIGO Penal Federal
# 12  CÓDIGO Penal Federal
# 13  CÓDIGO Penal Federal
# 14  CÓDIGO Penal Federal
# 15  CÓDIGO Penal Federal
# 16  CÓDIGO Penal Federal
# 17  CÓDIGO Penal Federal
# 18  CÓDIGO Penal Federal
# 19  CÓDIGO Penal Federal

# %% [markdown]
# We could manually inspect some of these results, but that could potentially take a lot of time...

# %%
for i in results.text:
    print(i)
    print("--------------")
# Out:
#  309 Se deroga
#
# CAPITULO III
# Reglas comunes para lesiones y homicidio
#
#
# --------------
#  313 Si el occiso o suicida fuere menor de edad o padeciere alguna de las formas de enajenación mental se aplicarán al homicida o instigador las sanciones señaladas al homicidio calificado o a las lesiones calificadas
#
#
# --------------
#  59 Bis Se deroga
#
# CAPITULO II
# Aplicación de sanciones a los delitos culposos
#
#
# --------------
#  302 Comete el delito de homicidio el que priva de la vida a otro
#
#
# --------------
#  320 Al responsable de un homicidio calificado se le impondrán de treinta a sesenta años de prisión
#
#
# --------------
#  307 Al responsable de cualquier homicidio simple intencional que no tenga prevista una sanción especial en este Código se le impondrán de doce a veinticuatro años de prisión
#
#
# --------------
#  301 De las lesiones que a una persona cause algún animal bravío será responsable el que con esa intención lo azuce o lo suelte o haga esto último por descuido
#
# CAPITULO II
# Homicidio
#
#
# --------------
#  137 Cuando durante una rebelión se cometan los delitos de homicidio robo secuestro despojo incendio saqueo u otros delitos se aplicarán las reglas del concurso
#
#    Los rebeldes no serán responsables de los homicidios ni de las lesiones inferidas en el acto de un combate pero de los que se causen fuera del mismo serán responsables tanto el que los manda como el que los permita y los que inmediatamente los ejecuten
#
#
# --------------
#  315 Bis Se impondrá la pena del artículo 320 de este Código cuando el homicidio sea cometido intencionalmente a propósito de una violación o un robo por el sujeto activo de éstos contra su víctima o víctimas
#
#    También se aplicará la pena a que se refiere el artículo 320 de este Código cuando el homicidio se cometiera intencionalmente en casahabitación habiéndose penetrado en la misma de manera furtiva con engaño o violencia o sin permiso de la persona autorizada para darlo
#
#
# --------------
#  308 Si el homicidio se comete en riña se aplicará a su autor de cuatro a doce años de prisión
#
#    Si el homicidio se comete en duelo se aplicará a su autor de dos a ocho años de prisión
#
#    Además de lo dispuesto en los artículos 51 y 52 para la fijación de las penas dentro de los mínimos y máximos anteriormente señalados se tomará en cuenta quién fue el provocado y quién el provocador así como la mayor o menor importancia de la provocación
#
#
# --------------
#  315 Se entiende que las lesiones y el homicidio son calificados cuando se cometen con premeditación con ventaja con alevosía o a traición
#
#    Hay premeditación siempre que el reo cause intencionalmente un lesión después de haber reflexionado sobre el delito que va a cometer
#
#    Se presumirá que existe premeditación cuando las lesiones o el homicidio se cometan por inundación incendio minas bombas o explosivos por medio de venenos o cualquiera otra sustancia nociva a la salud contagio venéreo asfixia o enervantes o por retribución dada o prometida por tormento motivos depravados o brutal ferocidad
#
#
# --------------
#  61 En los casos a que se refiere la primera parte del primer párrafo del artículo anterior se exceptúa la reparación del daño Siempre que al delito doloso corresponda sanción alternativa que incluya una pena no privativa de libertad aprovechará esa situación al responsable de delito culposo
#
#
# --------------
#  322 Además de las sanciones que señalan los dos capítulos anteriores los jueces podrán si lo creyeren conveniente
#
#    I Declarar a los reos sujetos a la vigilancia de la policía y
#
#    II Prohibirles ir a determinado lugar Municipio Distrito o Estado o residir en él
#
# CAPITULO IV
# Homicidio en razón del parentesco o relación
#
#
# --------------
#  341 Al que habiendo atropellado a una persona culposa o fortuitamente no le preste auxilio o no solicite la asistencia que requiere pudiendo hacerlo se le impondrá de quince a sesenta jornadas de trabajo en favor de la comunidad independientemente de la pena que proceda por el delito que con el atropellamiento se cometa
#
#
# --------------
#  321 Bis No se procederá contra quien culposamente ocasione lesiones u homicidio en agravio de un ascendiente o descendiente consanguíneo en línea recta hermano cónyuge concubino adoptante o adoptado salvo que el autor se encuentre bajo el efecto de bebidas embriagantes de estupefacientes o psicotrópicos sin que medie prescripción médica o bien que no auxiliare a la víctima
#
#
# --------------
#  66 En caso de que el error a que se refiere el inciso a de la fracción VIII del artículo 15 sea vencible se impondrá la punibilidad del delito culposo si el hecho de que se trata admite dicha forma de realización Si el error vencible es el previsto en el inciso b de dicha fracción la pena será de hasta una tercera parte del delito que se trate
#
# CAPITULO V
# Tratamiento de inimputables y de quienes tengan el hábito o la necesidad de consumir estupefacientes o psicotrópicos en internamiento o en libertad
#
#
# --------------
#  60 En los casos de delitos culposos se impondrá hasta la cuarta parte de las penas y medidas de seguridad asignadas por la ley al tipo básico del delito doloso con excepción de aquéllos para los que la ley señale una pena específica Además se impondrá en su caso suspensión hasta de tres años de derechos para ejercer profesión oficio autorización licencia o permiso
#
#    Las sanciones por delitos culposos sólo se impondrán en relación con los delitos previstos en los siguientes artículos 150 167 fracción VI 169 199 Bis 289 parte segunda 290 291 292 293 302 307 323 397 399 414 primer párrafo y tercero en su hipótesis de resultado 415 fracciones I y II y último párrafo en su hipótesis de resultado 416 420 fracciones I II III y V y 420 Bis fracciones I II y IV de este Código
#
#    Cuando a consecuencia de actos u omisiones culposos calificados como graves que sean imputables al personal que preste sus servicios en una empresa ferroviaria aeronáutica naviera o de cualesquiera otros transportes de servicio público federal o local se caucen homicidios de dos o más personas la pena será de cinco a veinte años de prisión destitución del empleo cargo o comisión e inhabilitación para obtener otros de la misma naturaleza Igual pena se impondrá cuando se trate de transporte de servicio escolar
#
#    La calificación de la gravedad de la culpa queda al prudente arbitrio del juez quien deberá tomar en consideración las circunstancias generales señaladas en el artículo 52 y las especiales siguientes
#
# I 	La mayor o menor facilidad de prever y evitar el daño que resultó
#
# II 	El deber del cuidado del inculpado que le es exigible por las circunstancias y condiciones personales que el oficio o actividad que desempeñe le impongan
#
# III 	Si el inculpado ha delinquido anteriormente en circunstancias semejantes
#
# IV 	Si tuvo tiempo para obrar con la reflexión y cuidado necesarios y
#
# V 	El estado del equipo vías y demás condiciones de funcionamiento mecánico tratándose de infracciones cometidas en los servicios de empresas transportadoras y en general por conductores de vehículos
#
# VI 	Se deroga
#
#
# --------------
#  71 El juez dejará sin efecto la sustitución y ordenará que se ejecute la pena de prisión impuesta cuando el sentenciado no cumpla con las condiciones que le fueran señaladas para tal efecto salvo que el juzgador estime conveniente apercibirlo de que si se incurre en nueva falta se hará efectiva la sanción sustituida o cuando al sentenciado se le condene por otro delito Si el nuevo delito es culposo el juez resolverá si se debe aplicar la pena sustituida
#
#    En caso de hacerse efectiva la pena de prisión sustituida se tomará en cuenta el tiempo durante el cual el sentenciado hubiera cumplido la sanción sustitutiva
#
#
# --------------
#  228 Los profesionistas artistas o técnicos y sus auxiliares serán responsables de los delitos que cometan en el ejercicio de su profesión en los términos siguientes y sin perjuicio de las prevenciones contenidas en la Ley General de Salud o en otras normas sobre ejercicio profesional en su caso
#
#    I Además de las sanciones fijadas para los delitos que resulten consumados según sean dolosos o culposos se les aplicará suspensión de un mes a dos años en el ejercicio de la profesión o definitiva en caso de reincidencia y
#
#    II Estarán obligados a la reparación del daño por sus actos propios y por los de sus auxiliares cuando éstos obren de acuerdo con las instrucciones de aquéllos
#
#
# --------------
#  280 Se impondrá prisión de tres días a dos años o de 30 a 90 días multa
#
#    I Al que oculte destruya o sepulte un cadáver o un feto humano sin la orden de la autoridad que deba darla o sin los requisitos que exijan los Códigos Civil y Sanitario o leyes especiales
#
#    II Al que oculte destruya o sin la licencia correspondiente sepulte el cadáver de una persona siempre que la muerte haya sido a consecuencia de golpes heridas u otras lesiones si el reo sabía esa circunstancia
#
#    En este caso no se aplicará sanción a los ascendientes o descendientes cónyuge o hermanos del responsable del homicidio y
#
#    III Al que exhume un cadáver sin los requisitos legales o con violación de derechos
#
#
# --------------

# %% [markdown]
# Let's instead build an n-gram model that attempts to predict which of these look like articles that have a answer with sanctions, penalties, of fines. Then let's get those probabilities and show only the results that have a high probability of being an answer.

# %%
clf = retrieve_model()
clfs = clf.predict(results)
probs = [math.exp(i)-1 for i in clf.predict(results)]

# %%
print("Maybe these are your results...\n")
for i in range(len(results.text)):
    if probs[i] > 0:
        print("--------------")
        print(results.text[i])
# Out:
# Maybe these are your results...
#
# --------------
#  60 En los casos de delitos culposos se impondrá hasta la cuarta parte de las penas y medidas de seguridad asignadas por la ley al tipo básico del delito doloso con excepción de aquéllos para los que la ley señale una pena específica Además se impondrá en su caso suspensión hasta de tres años de derechos para ejercer profesión oficio autorización licencia o permiso
#
#    Las sanciones por delitos culposos sólo se impondrán en relación con los delitos previstos en los siguientes artículos 150 167 fracción VI 169 199 Bis 289 parte segunda 290 291 292 293 302 307 323 397 399 414 primer párrafo y tercero en su hipótesis de resultado 415 fracciones I y II y último párrafo en su hipótesis de resultado 416 420 fracciones I II III y V y 420 Bis fracciones I II y IV de este Código
#
#    Cuando a consecuencia de actos u omisiones culposos calificados como graves que sean imputables al personal que preste sus servicios en una empresa ferroviaria aeronáutica naviera o de cualesquiera otros transportes de servicio público federal o local se caucen homicidios de dos o más personas la pena será de cinco a veinte años de prisión destitución del empleo cargo o comisión e inhabilitación para obtener otros de la misma naturaleza Igual pena se impondrá cuando se trate de transporte de servicio escolar
#
#    La calificación de la gravedad de la culpa queda al prudente arbitrio del juez quien deberá tomar en consideración las circunstancias generales señaladas en el artículo 52 y las especiales siguientes
#
# I 	La mayor o menor facilidad de prever y evitar el daño que resultó
#
# II 	El deber del cuidado del inculpado que le es exigible por las circunstancias y condiciones personales que el oficio o actividad que desempeñe le impongan
#
# III 	Si el inculpado ha delinquido anteriormente en circunstancias semejantes
#
# IV 	Si tuvo tiempo para obrar con la reflexión y cuidado necesarios y
#
# V 	El estado del equipo vías y demás condiciones de funcionamiento mecánico tratándose de infracciones cometidas en los servicios de empresas transportadoras y en general por conductores de vehículos
#
# VI 	Se deroga
#
#
# --------------
#  71 El juez dejará sin efecto la sustitución y ordenará que se ejecute la pena de prisión impuesta cuando el sentenciado no cumpla con las condiciones que le fueran señaladas para tal efecto salvo que el juzgador estime conveniente apercibirlo de que si se incurre en nueva falta se hará efectiva la sanción sustituida o cuando al sentenciado se le condene por otro delito Si el nuevo delito es culposo el juez resolverá si se debe aplicar la pena sustituida
#
#    En caso de hacerse efectiva la pena de prisión sustituida se tomará en cuenta el tiempo durante el cual el sentenciado hubiera cumplido la sanción sustitutiva
#
#
# --------------
#  228 Los profesionistas artistas o técnicos y sus auxiliares serán responsables de los delitos que cometan en el ejercicio de su profesión en los términos siguientes y sin perjuicio de las prevenciones contenidas en la Ley General de Salud o en otras normas sobre ejercicio profesional en su caso
#
#    I Además de las sanciones fijadas para los delitos que resulten consumados según sean dolosos o culposos se les aplicará suspensión de un mes a dos años en el ejercicio de la profesión o definitiva en caso de reincidencia y
#
#    II Estarán obligados a la reparación del daño por sus actos propios y por los de sus auxiliares cuando éstos obren de acuerdo con las instrucciones de aquéllos
#
#
# --------------
#  280 Se impondrá prisión de tres días a dos años o de 30 a 90 días multa
#
#    I Al que oculte destruya o sepulte un cadáver o un feto humano sin la orden de la autoridad que deba darla o sin los requisitos que exijan los Códigos Civil y Sanitario o leyes especiales
#
#    II Al que oculte destruya o sin la licencia correspondiente sepulte el cadáver de una persona siempre que la muerte haya sido a consecuencia de golpes heridas u otras lesiones si el reo sabía esa circunstancia
#
#    En este caso no se aplicará sanción a los ascendientes o descendientes cónyuge o hermanos del responsable del homicidio y
#
#    III Al que exhume un cadáver sin los requisitos legales o con violación de derechos

# %% [markdown]
# ## Let's try a query of your own!

# %%
# question = "¿Cuál es el castigo por extraer hidrocarburos ilegalmente?" 
# Translation: What is penalty for illegaly extracting hydrocarbons?

# %%
question = "¿Cuál es la multa por traición a la patria?" 
# Translation: What is penalty for not paying taxes?

# %%
query.set_question(question, question_json)
query.get_query(stopwords)
query.add_words(["multa", "sanción"])
words = list(query.query)
words
# Out:
# http://store.apicultur.com/api/sinonimosporpalabra/1.0.0/traición
# Bearer f7JE_2svUVwP5ARGfw8aQhnLXlga
# http://store.apicultur.com/api/sinonimosporpalabra/1.0.0/patria
# Bearer f7JE_2svUVwP5ARGfw8aQhnLXlga
# ['nación',
#  'exclamen',
#  'patriotismo',
#  'Patria',
#  'alevosía',
#  'ciudadanía',
#  'patria',
#  'sanción',
#  'traición',
#  'deslealtad',
#  'nacionalidad',
#  'legarnos',
#  'multa']

# %%
test = ScoreParagraphs(question, words, stem=True)
results = test.texts(top_results, method='bm25')
# Out:
# Working with stemmed words: ['nacion', 'exclam', 'patriot', 'patri', 'alev', 'ciudadan', 'patri', 'sancion', 'traicion', 'deslealt', 'nacional', 'leg', 'mult']
#                                                  text     score  \
# 0    122 Se deroga\n   \nLIBRO SEGUNDO\n\nTITULO P...  4.676978
# 1    319 Se dice que obra a traición el que no sol...  1.535522
# 2    318 La alevosía consiste en sorprender intenc...  1.317167
# 3    295 Al que ejerciendo la patria potestad o la...  1.089244
# 4    409 Se impondrán de veinte a cien días multa ...  1.033274
# 5    206 El lenocinio se sancionará con prisión de...  0.983053
# 6    315 Se entiende que las lesiones y el homicid...  0.838950
# 7    335 Al que abandone a un niño incapaz de cuid...  0.788663
# 8    376 En todo caso de robo si el juez lo creyer...  0.758250
# 9    97 Cuando la conducta observada por el senten...  0.614068
# 10   366 Ter Comete el delito de tráfico de menore...  0.608689
# 11   128 Se aplicará la pena de prisión de cinco a...  0.603548
# 12   370 Cuando el valor de lo robado no exceda de...  0.563587
# 13   59 Bis Se deroga\n   \nCAPITULO II\nAplicació...  0.522848
# 14   94 El indulto no puede concederse sino de san...  0.522380
# 15   73 El Ejecutivo tratándose de delitos polític...  0.506282
# 16   159 El reo suspenso en su profesión u oficio ...  0.505434
# 17   104 La acción penal prescribe en un año si el...  0.486738
# 18   191 Al que ultraje el escudo de la República ...  0.473046
# 19   29 La sanción pecuniaria comprende la multa y...  0.452234
#
#                      Law
# 0   CÓDIGO Penal Federal
# 1   CÓDIGO Penal Federal
# 2   CÓDIGO Penal Federal
# 3   CÓDIGO Penal Federal
# 4   CÓDIGO Penal Federal
# 5   CÓDIGO Penal Federal
# 6   CÓDIGO Penal Federal
# 7   CÓDIGO Penal Federal
# 8   CÓDIGO Penal Federal
# 9   CÓDIGO Penal Federal
# 10  CÓDIGO Penal Federal
# 11  CÓDIGO Penal Federal
# 12  CÓDIGO Penal Federal
# 13  CÓDIGO Penal Federal
# 14  CÓDIGO Penal Federal
# 15  CÓDIGO Penal Federal
# 16  CÓDIGO Penal Federal
# 17  CÓDIGO Penal Federal
# 18  CÓDIGO Penal Federal
# 19  CÓDIGO Penal Federal

# %%
clf = retrieve_model()
clfs = clf.predict(results)
probs = [math.exp(i)-1 for i in clf.predict(results)]

# %%
print("Maybe these are your results...\n")
for i in range(len(results.text)):
    if probs[i] > 0:
        print("--------------")
        print(results.text[i])
# Out:
# Maybe these are your results...
#
# --------------
#  97 Cuando la conducta observada por el sentenciado refleje un alto grado de reinserción social y su liberación no represente un riesgo para la tranquilidad y seguridad públicas conforme al dictamen del órgano ejecutor de la sanción y no se trate de sentenciado por traición a la Patria espionaje terrorismo sabotaje genocidio delitos contra la salud violación delito intencional contra la vida y secuestro desaparición forzada tortura y trata de personas ni de reincidente por delito intencional se le podrá conceder indulto por el Ejecutivo Federal en uso de facultades discrecionales expresando sus razones y fundamentos en los casos siguientes
#
#    I Por los delitos de carácter político a que alude el artículo 144 de este Código
#
#    II Por otros delitos cuando la conducta de los responsables haya sido determinada por motivaciones de carácter político o social y
#
#    III Por delitos de orden federal o común en el Distrito Federal cuando el sentenciado haya prestado importantes servicios a la Nación y previa solicitud
#
#
# --------------
#  366 Ter Comete el delito de tráfico de menores quien traslade a un menor de dieciséis años de edad o lo entregue a un tercero de manera ilícita fuera del territorio nacional con el propósito de obtener un beneficio económico indebido por el traslado o la entrega del menor
#
#    Cometen el delito a que se refiere el párrafo anterior
#
#    I Quienes ejerzan la patria potestad o custodia sobre el menor aunque no haya sido declarada cuando realicen materialmente el traslado o la entrega o por haber otorgado su consentimiento para ello
#
#    II Los ascendientes sin límite de grado los parientes colaterales y por afinidad hasta el cuarto grado así como cualquier tercero que no tenga parentesco con el menor
#
#    Se entenderá que las personas a que se refiere el párrafo anterior actúan de manera ilícita cuando tengan conocimiento de que
#
#    a Quienes ejerzan la patria potestad o la custodia del menor no han otorgado su consentimiento expreso para el traslado o la entrega o
#
#    b Quienes ejerzan la patria potestad o la custodia del menor obtendrán un beneficio económico indebido por el traslado o la entrega
#
#    III La persona o personas que reciban al menor
#
#    A quienes cometan el delito a que se refiere el presente artículo se les impondrá una pena de tres a diez años de prisión y de cuatrocientos a mil días multa
#
#    Además de las sanciones señaladas en el párrafo anterior se privará de los derechos de patria potestad tutela o custodia a quienes en su caso teniendo el ejercicio de éstos cometan el delito a que se refiere el presente artículo
#
#    Se aplicarán hasta las dos terceras partes de las penas a las que se refiere este artículo cuando el traslado o entrega del menor se realicen en territorio nacional
#
#
# --------------
#  29 La sanción pecuniaria comprende la multa y la reparación del daño
#
#    La multa consiste en el pago de una cantidad de dinero al Estado que se fijará por días multa los cuales no podrán exceder de mil salvo los casos que la propia ley señale El día multa equivale a la percepción neta diaria del sentenciado en el momento de consumar el delito tomando en cuenta todos sus ingresos
#
#    Para los efectos de este Código el límite inferior del día multa será el equivalente al salario mínimo diario vigente en el lugar donde se consumó el delito Por lo que toca al delito continuado se atenderá al salario mínimo vigente en el momento consumativo de la última conducta Para el permanente se considerará el salario mínimo en vigor en el momento en que cesó la consumación
#
#    Cuando se acredite que el sentenciado no puede pagar la multa o solamente puede cubrir parte de ella la autoridad judicial podrá sustituirla total o parcialmente por prestación del trabajo en favor de la comunidad
#
#    Cada jornada de trabajo saldará un día multa Cuando no sea posible o conveniente la sustitución de la multa por la prestación de servicios la autoridad judicial podrá colocar al sentenciado en libertad bajo vigilancia que no excederá del número de días multa sustituidos
#
#    Si el sentenciado se negare sin causa justificada a cubrir el importe de la multa el Estado la exigirá mediante el procedimiento económico coactivo
#
#    En cualquier tiempo podrá cubrirse el importe de la multa descontándose de ésta la parte proporcional a las jornadas de trabajo prestado en favor de la comunidad o al tiempo de prisión que el sentenciado hubiere cumplido tratándose de la multa sustitutiva de la pena privativa de libertad caso en el cual la equivalencia será a razón de un día multa por un día de prisión
